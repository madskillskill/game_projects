# %%
import pygame
from pygame.locals import *

pygame.init()





sq_0_0 = pygame.Rect(0,0, 200, 200)
sq_1_0 = pygame.Rect(200,0, 200, 200)
sq_2_0 = pygame.Rect(400,0, 200, 200)
sq_0_1 = pygame.Rect(0,200, 200, 200)
sq_1_1 = pygame.Rect(200,200, 200, 200)
sq_2_1 = pygame.Rect(400,200, 200, 200)
sq_0_2 = pygame.Rect(0,400, 200, 200)
sq_1_2 = pygame.Rect(200,400, 200, 200)
sq_2_2 = pygame.Rect(400,400, 200, 200)

# game_grid = {sq_0_0: 0,
#              sq_1_0: 0,
#              sq_2_0: 0,
#              sq_0_1: 0,
#              sq_1_1: 0,
#              sq_2_1: 0,
#              sq_0_2: 0,
#              sq_1_2: 0,
#              sq_2_2: 0
#              }

game_grid = [0,0,0,
             0,0,0,
             0,0,0]


SCREEN_WIDTH = 600
SCREEN_HEIGHT = 600

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption('tic-tac-toe')

grid1, grid2, grid3, grid4 = pygame.Rect(200,0, 4, 600), pygame.Rect(400,0, 4, 600), pygame.Rect(0,200, 600, 4), pygame.Rect(0,400, 600, 4)

player = pygame.Rect((300,250, 50, 50))

run = True

screen.fill((255,255,255))

squares = [sq_0_0, sq_0_1, ]

def recolor(square, state):
    if game_grid[0] == 0:
        pygame.draw.rect(screen, (255,255,255), square)
    if game_grid[]
        
    # for i in game_grid:
    #     print(i)


while run:
    
    # screen.fill((255,255,255))
    
    pygame.draw.rect(screen, (0,0,0), grid1)
    pygame.draw.rect(screen, (0,0,0), grid2)
    pygame.draw.rect(screen, (0,0,0), grid3)
    pygame.draw.rect(screen, (0,0,0), grid4)
    
    pygame.draw.rect(screen, (255, 0, 0), player)
    key = pygame.key.get_pressed()
    if key[pygame.K_a] == True:
        player.move_ip(-1,0)
    elif key[pygame.K_d] == True:
        player.move_ip(1,0)
    elif key[pygame.K_w] == True:
        player.move_ip(0,-1)
    elif key[pygame.K_s] == True:
        player.move_ip(0,1)
    
    
    if key[pygame.K_KP1] == True:
        recolor
    if key[pygame.K_KP2] == True:
        pygame.draw.rect(screen, (50,50,50), sq_1_2)
    if key[pygame.K_KP3] == True:
        pygame.draw.rect(screen, (50,50,50), sq_2_2)
    if key[pygame.K_KP4] == True:
        pygame.draw.rect(screen, (50,50,50), sq_0_1)
    if key[pygame.K_KP5] == True:
        pygame.draw.rect(screen, (50,50,50), sq_1_1)
    if key[pygame.K_KP6] == True:
        pygame.draw.rect(screen, (50,50,50), sq_2_1)
    if key[pygame.K_KP7] == True:
        pygame.draw.rect(screen, (50,50,50), sq_0_0)
    if key[pygame.K_KP8] == True:
        pygame.draw.rect(screen, (50,50,50), sq_1_0)
    if key[pygame.K_KP9] == True:
        pygame.draw.rect(screen, (50,50,50), sq_2_0)
    
    # if key[pygame.K_KP1] == True:
    #     pygame.draw.rect(screen, (50,50,50), sq_0_2)
    # if key[pygame.K_KP2] == True:
    #     pygame.draw.rect(screen, (50,50,50), sq_1_2)
    # if key[pygame.K_KP3] == True:
    #     pygame.draw.rect(screen, (50,50,50), sq_2_2)
    # if key[pygame.K_KP4] == True:
    #     pygame.draw.rect(screen, (50,50,50), sq_0_1)
    # if key[pygame.K_KP5] == True:
    #     pygame.draw.rect(screen, (50,50,50), sq_1_1)
    # if key[pygame.K_KP6] == True:
    #     pygame.draw.rect(screen, (50,50,50), sq_2_1)
    # if key[pygame.K_KP7] == True:
    #     pygame.draw.rect(screen, (50,50,50), sq_0_0)
    # if key[pygame.K_KP8] == True:
    #     pygame.draw.rect(screen, (50,50,50), sq_1_0)
    # if key[pygame.K_KP9] == True:
    #     pygame.draw.rect(screen, (50,50,50), sq_2_0)
    
    pygame.draw.rect(screen, (0,0,0), grid1)
    pygame.draw.rect(screen, (0,0,0), grid2)
    pygame.draw.rect(screen, (0,0,0), grid3)
    pygame.draw.rect(screen, (0,0,0), grid4)
    
    
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            run = False
    pygame.display.update()
pygame.quit()

# %%
for i in game_grid:
        print(i)
# Out:
# 0.0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
